# %%
# import os
# dataroot='/content/drive/MyDrive/585_data/alt_images/'

# img_folder = os.path.join(dataroot, "images/val/")
# gt_folder = os.path.join(dataroot, "ground_truth/val/")
        
# img_filenames = sorted(os.listdir(img_folder))
# gt_filenames = sorted(os.listdir(gt_folder))

# img_file_names = [os.path.splitext(f)[0] for f in img_filenames]
# gt_file_names = [os.path.splitext(f)[0] for f in gt_filenames]

# num_matches = 0
# for img_file in img_filenames:
#     img_file_name = os.path.splitext(img_file)[0]
#     gt_file = f"{img_file_name}.png"
#     if gt_file in gt_filenames:
#         num_matches += 1
#     else:
#         os.remove(os.path.join(img_folder, img_file))

# print(f"{num_matches} images have a match in the other folder.")

# %%
# import shutil
# import os

# # source_dir = "/content/drive/My Drive/585_data/alt_images/images/JPEGImages/"
# # dest_dir= "/content/drive/My Drive/585_data/alt_images/images/val/"

# source_dir = "/content/drive/My Drive/585_data/alt_images/ground_truth/improved_contours/"
# dest_dir= "/content/drive/My Drive/585_data/alt_images/ground_truth/val/"
# n = 200 

# files = os.listdir(source_dir)
# files = sorted(files)

# for file in files[:n]:
#     src_path = os.path.join(source_dir, file)
#     dest_path = os.path.join(dest_dir, file)
#     shutil.move(src_path, dest_path)

# files = os.listdir(dest_dir)
# print(files)

# %%
# dataroot='/content/drive/MyDrive/585_data/alt_images/'

# img_folder = os.path.join(dataroot, "images/JPEGImages/")
# gt_folder = os.path.join(dataroot, "ground_truth/improved_contours/")
        
# img_filenames = sorted(os.listdir(img_folder))
# gt_filenames = sorted(os.listdir(gt_folder))

# img_file_names = [os.path.splitext(f)[0] for f in img_filenames]
# gt_file_names = [os.path.splitext(f)[0] for f in gt_filenames]

# num_matches = 0
# for img_file in img_filenames:
#     img_file_name = os.path.splitext(img_file)[0]
#     gt_file = f"{img_file_name}.png"
#     if gt_file in gt_filenames:
#         num_matches += 1
#     else:
#         os.remove(os.path.join(img_folder, img_file))

# print(f"{num_matches} images have a match in the other folder.")

# for gt_file in gt_filenames:
#     gt_file_name = os.path.splitext(gt_file)[0]
#     img_file = f"{gt_file_name}.jpg"
#     if img_file not in img_filenames:
#         os.remove(os.path.join(gt_folder, gt_file))

# %%
#from  https://stackoverflow.com/questions/66678052/how-to-calculate-the-mean-and-the-std-of-cifar10-data
# def get_mean_std(trainLoader):
#     imgs = None
#     for batch in trainLoader:
#         image_batch = batch[0]
#         if imgs is None:
#             imgs = image_batch.cpu()
#         else:
#             imgs = torch.cat([imgs, image_batch.cpu()], dim=0)
#     imgs = imgs.numpy()
    
#     # calculate mean over each channel (r,g,b)
#     mean_r = imgs[:,0,:,:].mean()
#     mean_g = imgs[:,1,:,:].mean()
#     mean_b = imgs[:,2,:,:].mean()
#     print(mean_r,mean_g,mean_b)

#     # calculate std over each channel (r,g,b)
#     std_r = imgs[:,0,:,:].std()
#     std_g = imgs[:,1,:,:].std()
#     std_b = imgs[:,2,:,:].std()
#     print(std_r,std_g,std_b)

# get_mean_std(trainLoader=dataloader)
